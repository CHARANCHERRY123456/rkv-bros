# %%
import pandas as pd

# %%
r20df = pd.read_csv("./the_data_with_rank.csv")

# %%
r20df.head(5)
# Out:
#        sid                       name  gender     cetHtNo  stream  classP1  \
# 0  R200001  POSA VENKATA SIVA SHANKAR    MALE  2111020143   M.P.C     G004
# 1  R200002    NANDINENI HARSHAVARDHAN    MALE  2212027156   M.P.C     G004
# 2  R200003            GAJULA HARSHITH    MALE  2715001069   M.P.C     G005
# 3  R200004  KONANGI LAKSHMI NARASIMHA    MALE  2010015101   M.P.C     G004
# 4  R200005     ELUGOTI HARSHA VARDHAN    MALE  2212026173   M.P.C     G006
#
#    caste              classP2         dob                      father  ...  \
# 0   BC-B  Class-12 (S017-AB1)  10/06/2003            POSA SUBBARAYUDU  ...
# 1     OC   Class-9 (S010-AB1)  09/04/2004     NANDINENI VENKATARAMUDU  ...
# 2   BC-B  Class-13 (S018-AB1)  13/05/2004             GAJULA SRINIVAS  ...
# 3   BC-A   Class-9 (S010-AB1)  10/07/2004            K GOPALA KRISHNA  ...
# 4   BC-B  Class-14 (S019-AB1)  09/09/2004  ELUGOTI SURYA PRAKASH BABU  ...
#
#    e1sem1  e1sem2  e2sem1   e2sem2   branch   cgpa  \
# ...

# %%
r20df.columns

# %%
r20df["batch"] = "R20"

# %%
r20df.to_csv("r20.csv" , index=False)
